# %% [markdown]
# # 2. Descrição
#
# **Dataset**<br>
#
# cars85.data
# * Este dataset traz informações relacionadas a veículos automotivos.
# * O arquivo deverá ser alterado para .CSV e importado para o Google Colab.
#
# cars85.names
# * Este arquivo é muito importante pois descreve os nomes das colunas do Dataset.

# %% [markdown]
# # 3. Importar Bibliotecas

# %%
# Importar as blibliotecas que serão utilizadas no projeto
import pandas as pd
import warnings
import os
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
warnings.filterwarnings('ignore')

# Remover notação científica do DataFrame
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Mostrar todas as colunas
pd.options.display.max_columns = None

# %% [markdown]
# # 4. Carregar Arquivo .csv
# Carregue o seu arquivo que foi baixado a partir do Kaggle

# %%
# Use o comando read.csv para carregar os dados e associar a um dataframe
# Acessando o diretório do database
path = './cars85 1.csv'

# %%
# Use o comando read_csv para carregar os dados e associar a um dataframe
df = pd.read_csv('./cars85_formatted.csv')
df = df.replace("?", np.nan)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front       88.60
# ...

# %% [markdown]
# Fomatos de arquivos aceito pelo python <br>
#
# ![Formats_files.png](data:image/png;base64,...)

# %% [markdown]
# # 5. Analizando o DataBase
#
# Basic Insights of Dataset - Data Types: <br>
#
# ![image.png](data:image/png;base64,...)

# %%
# 1. Exiba os nomes das colunas do seu database
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-height', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
# 2. Exiba o tipos de dados das colunas
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-height            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# 3. Exibir dados estatísticos das colunas quantitativas

# %%
# 4. Exibir dados estatísticos de totas as colunas quantitativas e qualitativas

# %%
# 5. Exibir informações do Dataset
df.info
# Out:
# <bound method DataFrame.info of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# ...

# %%
# 6. Alterar Nomes das Colunas
df.columns = ["simbolo", "perca_normalizada", "marca", "tipo_combustivel", "aspirador", "numero_portas", "estilo", "tipo_roda", "posicao_motor", "base_roda", "comprimento", "largura", "altura", "peso_freio", "tipo_motor", "numero_cilindros", "tamanho_motor", "sistema_combustivel", "calibre", "distancia_pistao_cilindro", "razao_compressao", "cavalo", "pico-rpm", "mpg_cidade", "mpg_avenidade", "preço"]
df
# Out:
#      simbolo perca_normalizada        marca tipo_combustivel aspirador  \
# 0          3               NaN  alfa-romero              gas       std
# 1          3               NaN  alfa-romero              gas       std
# 2          1               NaN  alfa-romero              gas       std
# 3          2               164         audi              gas       std
# 4          2               164         audi              gas       std
# ..       ...               ...          ...              ...       ...
# 200       -1                95        volvo              gas       std
# 201       -1                95        volvo              gas     turbo
# 202       -1                95        volvo              gas       std
# 203       -1                95        volvo           diesel     turbo
# 204       -1                95        volvo              gas     turbo
#
#     numero_portas       estilo tipo_roda posicao_motor  base_roda  \
# ...

# %% [markdown]
# # 6. Conexão com Banco de Dados
#
# Basic Insights of Dataset - Data Types: <br>

# %%
# 7. Connecting the Python with a Database
import mysql.connector
from mysql.connector import (connection)
from mysql.connector import errorcode

try:
	db_connection = connection.MySQLConnection(host='127.0.0.1', user='root', password='password', database='mysql')
	print("Database connection made!")
except mysql.connector.Error as error:
	if error.errno == errorcode.ER_BAD_DB_ERROR:
		print("Database doesn't exist")
	elif error.errno == errorcode.ER_ACCESS_DENIED_ERROR:
		print("User name or password is wrong")
	else:
		print(error)
else:
	db_connection.close()
# Out:
# Database connection made!

# %% [markdown]
# # 7. Gráficos

# %%
# Importar Biblioteca Seaborn
import seaborn as sns

# %%
sns.catplot(x='fuel-type', y='num-of-cylinders', data=df)

# %%
sns.catplot(x='fuel-type', y='price', data=df)

# %%
sns.relplot(x='num-of-cylinders', y='make', hue='fuel-type', col='fuel-type', data=df)

# %% [markdown]
# # 8. Exercícios
#
# Responda as questões abaixo <br>
# Cada questão vale **0,1** ponto

# %%
# 8.1. Alterar os nomes das colunas para portugues (0,1)
df.columns = ["simbolo", "perca_normalizada", "marca", "tipo_combustivel", "aspirador", "numero_portas", "estilo", "tipo_roda", "posicao_motor", "base_roda", "comprimento", "largura", "altura", "peso_freio", "tipo_motor", "numero_cilindros", "tamanho_motor", "sistema_combustivel", "calibre", "distancia_pistao_cilindro", "razao_compressao", "cavalo", "pico-rpm", "mpg_cidade", "mpg_avenidade", "preço"]
df
# Out:
#      simbolo perca_normalizada        marca tipo_combustivel aspirador  \
# 0          3               NaN  alfa-romero              gas       std
# 1          3               NaN  alfa-romero              gas       std
# 2          1               NaN  alfa-romero              gas       std
# 3          2               164         audi              gas       std
# 4          2               164         audi              gas       std
# ..       ...               ...          ...              ...       ...
# 200       -1                95        volvo              gas       std
# 201       -1                95        volvo              gas     turbo
# 202       -1                95        volvo              gas       std
# 203       -1                95        volvo           diesel     turbo
# 204       -1                95        volvo              gas     turbo
#
#     numero_portas       estilo tipo_roda posicao_motor  base_roda  \
# ...

# %%
# 8.2. Alterar os Dados da Coluna Cilindros para Portugues (0,1)
df['numero_cilindros'][df['numero_cilindros'] == 'four'] = 4
df['numero_cilindros'][df['numero_cilindros'] == 'six'] = 6
df['numero_cilindros'][df['numero_cilindros'] == 'five'] = 5
df['numero_cilindros'][df['numero_cilindros'] == 'three'] = 3
df['numero_cilindros'][df['numero_cilindros'] == 'twelve'] = 12
df['numero_cilindros'][df['numero_cilindros'] == 'two'] = 2
df['numero_cilindros'][df['numero_cilindros'] == 'eight'] = 8
df
# Out:
#      simbolo perca_normalizada        marca tipo_combustivel aspirador  \
# 0          3               NaN  alfa-romero              gas       std
# 1          3               NaN  alfa-romero              gas       std
# 2          1               NaN  alfa-romero              gas       std
# 3          2               164         audi              gas       std
# 4          2               164         audi              gas       std
# ..       ...               ...          ...              ...       ...
# 200       -1                95        volvo              gas       std
# 201       -1                95        volvo              gas     turbo
# 202       -1                95        volvo              gas       std
# 203       -1                95        volvo           diesel     turbo
# 204       -1                95        volvo              gas     turbo
#
#     numero_portas       estilo tipo_roda posicao_motor  base_roda  \
# ...

# %%
# 8.3. Criar uma tabela apenas com colunas QUANTITATIVAS (0,1)
dfQuantitativas = df.select_dtypes(include=[np.number])
dfQuantitativas
# Out:
#      simbolo  base_roda  comprimento  largura  altura  peso_freio  \
# 0          3      88.60       168.80    64.10   48.80        2548
# 1          3      88.60       168.80    64.10   48.80        2548
# 2          1      94.50       171.20    65.50   52.40        2823
# 3          2      99.80       176.60    66.20   54.30        2337
# 4          2      99.40       176.60    66.40   54.30        2824
# ..       ...        ...          ...      ...     ...         ...
# 200       -1     109.10       188.80    68.90   55.50        2952
# 201       -1     109.10       188.80    68.80   55.50        3049
# 202       -1     109.10       188.80    68.90   55.50        3012
# 203       -1     109.10       188.80    68.90   55.50        3217
# 204       -1     109.10       188.80    68.90   55.50        3062
#
#      tamanho_motor  razao_compressao  mpg_cidade  mpg_avenidade
# 0              130              9.00          21             27
# ...

# %%
# 8.4. Criar uma tabela apenas com colunas QUALITATIVAS (0,1)
dfQualitativas = df.select_dtypes(include=[np.object])
dfQualitativas
# Out:
#     perca_normalizada        marca tipo_combustivel aspirador numero_portas  \
# 0                 NaN  alfa-romero              gas       std           two
# 1                 NaN  alfa-romero              gas       std           two
# 2                 NaN  alfa-romero              gas       std           two
# 3                 164         audi              gas       std          four
# 4                 164         audi              gas       std          four
# ..                ...          ...              ...       ...           ...
# 200                95        volvo              gas       std          four
# 201                95        volvo              gas     turbo          four
# 202                95        volvo              gas       std          four
# 203                95        volvo           diesel     turbo          four
# 204                95        volvo              gas     turbo          four
#
# ...

# %%
# 8.5. Verificar a quantidade de valores Nulos nas colunas (0,1)
df.isna().sum().sum()
# Out:
# 59

# %%
# 8.6. Verificar os valores únicos da coluna Cilindros e Combustível (0,1)
print(df.value_counts("tipo_combustivel"))
print(df.value_counts('numero_cilindros'))
# Out:
# tipo_combustivel
# gas       185
# diesel     20
# dtype: int64
# numero_cilindros
# 4         159
# 6          24
# 5          11
# eight       5
# two         4
# twelve      1
# three       1
# dtype: int64

# %%
# 8.7. Exibir as 5 últimas linhas do DataFrame (0,1)
df.tail()
# Out:
#      simbolo perca_normalizada  marca tipo_combustivel aspirador  \
# 200       -1                95  volvo              gas       std
# 201       -1                95  volvo              gas     turbo
# 202       -1                95  volvo              gas       std
# 203       -1                95  volvo           diesel     turbo
# 204       -1                95  volvo              gas     turbo
#
#     numero_portas estilo tipo_roda posicao_motor  base_roda  comprimento  \
# 200          four  sedan       rwd         front     109.10       188.80
# 201          four  sedan       rwd         front     109.10       188.80
# 202          four  sedan       rwd         front     109.10       188.80
# 203          four  sedan       rwd         front     109.10       188.80
# 204          four  sedan       rwd         front     109.10       188.80
#
#      largura  altura  peso_freio tipo_motor numero_cilindros  tamanho_motor  \
# ...

# %%
# 8.8. Deletar uma coluna do DataFrame (0,1)
df.drop('simbolo', inplace=True, axis=1)
df
# Out:
#     perca_normalizada        marca tipo_combustivel aspirador numero_portas  \
# 0                 NaN  alfa-romero              gas       std           two
# 1                 NaN  alfa-romero              gas       std           two
# 2                 NaN  alfa-romero              gas       std           two
# 3                 164         audi              gas       std          four
# 4                 164         audi              gas       std          four
# ..                ...          ...              ...       ...           ...
# 200                95        volvo              gas       std          four
# 201                95        volvo              gas     turbo          four
# 202                95        volvo              gas       std          four
# 203                95        volvo           diesel     turbo          four
# 204                95        volvo              gas     turbo          four
#
# ...

# %%
# 8.9. Crie um gráfico com duas variáveis e explique a relação apresentada nos dados (0,1)
sns.catplot(x='peso_freio', y='mpg_cidade', data=df)
# Explicação: quanto menor é o peso do freio, maior é o desempenho na cidade

# %%
# 8.10. A seu critério, utilize algum dos comandos Python já apresentados (0,1)
#       em aulas e faça alguma análise no dataset apresentado
sns.relplot(x='numero_cilindros', y='mpg_cidade', hue='tipo_roda', col='tipo_roda', data=df)
# no geral os carros com maior desempenho na cidade tem 4 cilindros e são tração dianteira
